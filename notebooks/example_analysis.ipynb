# %% [markdown]
# # Time Series Analysis Example
#
# This notebook demonstrates the basic usage of the time series analysis framework.

# %%
# Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# Import our modules
from src.data_generator import TimeSeriesGenerator
from src.models import OnlineLearningModel, ARIMAModel, AnomalyDetector
from src.visualization import TimeSeriesVisualizer
